# %%
import sys
import os

sys.path.insert(0, os.path.abspath(".."))

from dotenv import load_dotenv

load_dotenv("../.env")
# Out:
# True

# %%
from configs.config import Config, load_video_urls

from src.notebook_helpers import (
    sanity_check_env,
    check_mongo_connection,
    display_video_url_validation,
    display_jobs_status,
    display_jobs_summary,
)

from src.utils import extract_and_validate_urls

from src.mongo_utils import (
    get_collection,
    setup_index,
)

from src import ingestion_tracker as tracker

# %%
# Validasi konfigurasi environment
sanity_check_env(Config)

# Test koneksi MongoDB Atlas
check_mongo_connection(Config.mongo.URI)
# Out:
# [OK] Konfigurasi environment valid.
#   MongoDB  : mongodb+srv://dhananjaya1103_db_user:jokowi123@jokowi-sentiment.frcdg9j.mongodb.net/?retryWrites=true&w=majority&appName=jokowi-sentiment / youtube_sentiment
#   API Key  : **********Rkpk
#   Target   : 10000 komentar per video
# 2026-05-13 23:54:44 | INFO | mongo_utils | Koneksi MongoDB berhasil.
#
# [OK] Koneksi MongoDB berhasil: mongodb+srv://dhananjaya1103_db_user:jokowi123@jokowi-sentiment.frcdg9j.mongodb.net/?retryWrites=true&w=majority&appName=jokowi-sentiment
# True

# %%
urls = load_video_urls()

valid_entries, invalid_entries = extract_and_validate_urls(urls)

display_video_url_validation(
    valid_entries,
    invalid_entries,
)
urls = load_video_urls()

valid_entries, invalid_entries = extract_and_validate_urls(urls)

display_video_url_validation(
    valid_entries,
    invalid_entries,
)
# Out:
# ...
#   VALIDASI URL VIDEO
# ...
#   Valid   : 14 URL
#   Invalid : 0 URL
# ...
#
# [VALID]
#   [01] _8H_-uNHKL4  <-  https://www.youtube.com/watch?v=_8H_-uNHKL4&t=351s
#   [02] TcNSqpBPle4  <-  https://www.youtube.com/watch?v=TcNSqpBPle4
#   [03] UEocTRWhtsE  <-  https://www.youtube.com/watch?v=UEocTRWhtsE
#   [04] g7Et92hQ_yE  <-  https://www.youtube.com/watch?v=g7Et92hQ_yE&t=2237s
#   [05] 5btOJ_Wru2k  <-  https://www.youtube.com/watch?v=5btOJ_Wru2k
#   [06] tQKnVXSL7nc  <-  https://www.youtube.com/watch?v=tQKnVXSL7nc
#   [07] HcwZx39bP80  <-  https://www.youtube.com/watch?v=HcwZx39bP80
#   [08] UE2gk8vMgBQ  <-  https://www.youtube.com/watch?v=UE2gk8vMgBQ
#   [09] LgaDFmaTpak  <-  https://www.youtube.com/watch?v=LgaDFmaTpak
#   [10] u4zZ7gHRBaU  <-  https://www.youtube.com/watch?v=u4zZ7gHRBaU
#   [11] uxDGtbE72jk  <-  https://www.youtube.com/watch?v=uxDGtbE72jk
#   [12] 4yjXBLcjynU  <-  https://www.youtube.com/watch?v=4yjXBLcjynU
# ...

# %%
collection_jobs = get_collection(
    uri=Config.mongo.URI,
    db_name=Config.mongo.DB_NAME,
    collection_name=Config.mongo.COLLECTION_JOBS,
)

collection_raw = get_collection(
    uri=Config.mongo.URI,
    db_name=Config.mongo.DB_NAME,
    collection_name=Config.mongo.COLLECTION_RAW,
)

print("[OK] MongoDB collections berhasil dibuat.")
# Out:
# [OK] MongoDB collections berhasil dibuat.

# %%
setup_index(
    collection_jobs,
    "video_id",
    unique=True,
)

setup_index(
    collection_raw,
    "comment_id",
    unique=True,
)
# Out:
# 2026-05-13 23:54:54 | INFO | mongo_utils | Index dibuat pada field 'video_id' (unique=True)
# 2026-05-13 23:54:54 | INFO | mongo_utils | Index dibuat pada field 'comment_id' (unique=True)

# %%
print(valid_entries)
# Out:
# [('https://www.youtube.com/watch?v=_8H_-uNHKL4&t=351s', '_8H_-uNHKL4'), ('https://www.youtube.com/watch?v=TcNSqpBPle4', 'TcNSqpBPle4'), ('https://www.youtube.com/watch?v=UEocTRWhtsE', 'UEocTRWhtsE'), ('https://www.youtube.com/watch?v=g7Et92hQ_yE&t=2237s', 'g7Et92hQ_yE'), ('https://www.youtube.com/watch?v=5btOJ_Wru2k', '5btOJ_Wru2k'), ('https://www.youtube.com/watch?v=tQKnVXSL7nc', 'tQKnVXSL7nc'), ('https://www.youtube.com/watch?v=HcwZx39bP80', 'HcwZx39bP80'), ('https://www.youtube.com/watch?v=UE2gk8vMgBQ', 'UE2gk8vMgBQ'), ('https://www.youtube.com/watch?v=LgaDFmaTpak', 'LgaDFmaTpak'), ('https://www.youtube.com/watch?v=u4zZ7gHRBaU', 'u4zZ7gHRBaU'), ('https://www.youtube.com/watch?v=uxDGtbE72jk', 'uxDGtbE72jk'), ('https://www.youtube.com/watch?v=4yjXBLcjynU', '4yjXBLcjynU'), ('https://www.youtube.com/watch?v=UTvTHgjI_QI', 'UTvTHgjI_QI'), ('https://www.youtube.com/watch?v=BMcbB3SlU1M', 'BMcbB3SlU1M')]

# %%
video_entries = [
    {
        "video_id": vid,
        "video_url": url,
    }
    for url, vid in valid_entries
]

print(f"Total video valid: {len(video_entries)}")

for entry in video_entries:
    print(
        f"- {entry['video_id']} | "
        f"{entry['video_url']}"
    )
# Out:
# Total video valid: 14
# - _8H_-uNHKL4 | https://www.youtube.com/watch?v=_8H_-uNHKL4&t=351s
# - TcNSqpBPle4 | https://www.youtube.com/watch?v=TcNSqpBPle4
# - UEocTRWhtsE | https://www.youtube.com/watch?v=UEocTRWhtsE
# - g7Et92hQ_yE | https://www.youtube.com/watch?v=g7Et92hQ_yE&t=2237s
# - 5btOJ_Wru2k | https://www.youtube.com/watch?v=5btOJ_Wru2k
# - tQKnVXSL7nc | https://www.youtube.com/watch?v=tQKnVXSL7nc
# - HcwZx39bP80 | https://www.youtube.com/watch?v=HcwZx39bP80
# - UE2gk8vMgBQ | https://www.youtube.com/watch?v=UE2gk8vMgBQ
# - LgaDFmaTpak | https://www.youtube.com/watch?v=LgaDFmaTpak
# - u4zZ7gHRBaU | https://www.youtube.com/watch?v=u4zZ7gHRBaU
# - uxDGtbE72jk | https://www.youtube.com/watch?v=uxDGtbE72jk
# - 4yjXBLcjynU | https://www.youtube.com/watch?v=4yjXBLcjynU
# - UTvTHgjI_QI | https://www.youtube.com/watch?v=UTvTHgjI_QI
# - BMcbB3SlU1M | https://www.youtube.com/watch?v=BMcbB3SlU1M

# %%
tracker.register_jobs(
    collection_jobs,
    video_entries,
    overwrite_failed=True,
)

print("\nSemua job berhasil didaftarkan.")
# Out:
# Semua job berhasil didaftarkan.

# %%
# %store video_entries

print("\n[OK] video_entries berhasil disimpan.")
# Out:
# Stored 'video_entries' (list)
#
# [OK] video_entries berhasil disimpan.

# %% [markdown]
# Stop
